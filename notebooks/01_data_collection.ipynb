# %% [markdown]
# # Data Collection
# **Research Objective:** Build a provenance-preserving candidate pool.
# **Relevant RQ:** RQ1–RQ3.
# **Input:** The Met Collection API.
# **Method:** Call `src.collect_data` with caching, retries and de-duplication.
# **Expected Output:** `data/raw/met_objects_raw.csv`.

# %%
from src.collect_data import collect
# collect([...], max_objects=500)  # enable for a new run
