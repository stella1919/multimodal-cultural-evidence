# %% [markdown]
# # Data Quality and Cleaning
# **Research Objective:** Make missingness and selection decisions explicit.
# **Relevant RQ:** RQ1–RQ3.
# **Input:** Raw Met CSV.
# **Method:** Run quality assessment and transparent context rules.
# **Expected Output:** Processed pilot, ambiguity table and missingness figures.

# %%
from src.clean_data import quality_and_select
df = quality_and_select(300)
df.cultural_context.value_counts()
