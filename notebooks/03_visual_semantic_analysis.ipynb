# %% [markdown]
# # Visual and Semantic Analysis
# **Research Objective:** Compare visual form and metadata semantics.
# **Relevant RQ:** RQ1 and RQ2.
# **Input:** Validated images and structured metadata text.
# **Method:** Frozen OpenCLIP and multilingual sentence-transformer representations; cosine similarity and PCA/UMAP.
# **Expected Output:** Embeddings, pair tables and two embedding-space figures.

# %%
# Run from the repository root:
# PYTHONPATH=. python -m src.image_embedding
# PYTHONPATH=. python -m src.text_embedding
